# %% [markdown]
# Print

# %%
print("My name is :", "Mohab")
# Out:
# My name is : Mohab

# %% [markdown]
# Comments

# %%
print("This is a simple Python script.")
"""prints the sum of two numbers."""
print("The sum of 5 and 3 is:", 5 + 3)
# Out:
# This is a simple Python script.
# The sum of 5 and 3 is: 8

# %% [markdown]
# Format

# %%
print("my name is {x} and I am {y} years old".format(x="Mohab", y=22))
print("my name is {} and I am {} years old".format("Mohab", 22))
print("my name is {0} and I am {1} years old".format("Mohab", 22))
# Out:
# my name is Mohab and I am 22 years old
# my name is Mohab and I am 22 years old
# my name is Mohab and I am 22 years old

# %%
x = "Mohab"
y = 22
s = "ML"
print("my name is {x}, I am {y} years old and I'm Enrolled in {s} course".format(x=x,y=y,s=s))
# Out:
# my name is Mohab, I am 22 years old and I'm Enrolled in ML course

# %% [markdown]
# Slicing

# %%
name = "amit learning"
print(name[5:10:1])  # slicing with step
# Out:
# learn

# %% [markdown]
# String Function

# %%
x = "Mohab Islam"
print(x.upper())
# Out:
# MOHAB ISLAM

# %%
print(x)
# Out:
# Mohab Islam

# %%
x.replace("Islam", "Ahmed")
# Out:
# 'Mohab Ahmed'

# %%
print(x.upper())
# Out:
# MOHAB ISLAM

# %%
m_names = x.split()

# %%
print(m_names)
# Out:
# ['Mohab', 'Islam']

# %%
m_join = " ".join(m_names)

# %%
print(m_join)
# Out:
# Mohab Islam

# %%
print("Hello\nWorld")
print("Hello\bWorld")
print("Hello\tWorld")
# Out:
# Hello
# World
# HellWorld
# Hello	World

# %%
x = "mohab"
print(hex(id(x)))
# Out:
# 0x1ba9136fb40
